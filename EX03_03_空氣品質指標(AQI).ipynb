# %% [markdown]
# <a href="https://colab.research.google.com/github/gracee331/graczzz/blob/main/EX03_03_%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99(AQI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant status  so2    co     o3  o3_8hr  pm10  ...  \
# 0       基隆    基隆市   47       NaN     良好  1.3  0.20   54.0    51.0  10.0  ...
# 1       汐止    新北市   61     臭氧八小時     普通  1.9  0.22   69.0    58.0  13.0  ...
# 2       新店    新北市   97     臭氧八小時     普通  1.3  0.34   92.0    69.0   NaN  ...
# 3       土城    新北市   73     細懸浮微粒     普通  2.0  0.36  100.0    60.0  42.0  ...
# 4       板橋    新北市   74     臭氧八小時     普通  2.1  0.35   98.0    62.0  38.0  ...
#
#    wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg pm10_avg  \
# 0         0.8          23  2025/05/13 14:00:00     0.2       5.1       12
# 1           1          53  2025/05/13 14:00:00     0.3      10.2       18
# 2           3         331  2025/05/13 14:00:00     0.3      14.9       24
# 3           3         330  2025/05/13 14:00:00     0.4      20.7       32
# 4         3.3         349  2025/05/13 14:00:00     0.4      16.1       29
#
#   so2_avg   longitude   latitude  siteid
# 0       1  121.760056  25.129167       1
# 1       0  121.640810  25.066240       2
# 2       0  121.537778  24.977222       4
# 3       1  121.451861  24.982528       5
# 4       1  121.458667  25.012972       6
#
# [5 rows x 24 columns]

# %% [markdown]
# # 留下需要的欄位（'sitename', 'county','pollutant', 'status', 'aqi'）

# %%
df = df[['sitename', 'county', 'pollutant', 'status', 'aqi']]
df
# Out:
#        sitename county pollutant    status  aqi
# 0            基隆    基隆市       NaN        良好   47
# 1            汐止    新北市     臭氧八小時        普通   61
# 2            新店    新北市     臭氧八小時        普通   97
# 3            土城    新北市     細懸浮微粒        普通   73
# 4            板橋    新北市     臭氧八小時        普通   74
# ..          ...    ...       ...       ...  ...
# 81       屏東（琉球）    屏東縣     臭氧八小時        普通   80
# 82  台中市（和平區消防隊）    臺中市       NaN        良好   34
# 83       新北(樹林)    新北市     臭氧八小時        普通   74
# 84       臺南（南化）    臺南市       NaN        良好   42
# 85       屏東(枋山)    屏東縣     臭氧八小時  對敏感族群不健康  108
#
# [86 rows x 5 columns]

# %% [markdown]
# # 請找出空氣品質不良的測站（aqi > 100）

# %%
condition = df['aqi'] > 100
df[condition]
# Out:
#    sitename county pollutant    status  aqi
# 23       頭份    苗栗縣        臭氧  對敏感族群不健康  101
# 26       豐原    臺中市        臭氧  對敏感族群不健康  104
# 70       馬祖    連江縣     臭氧八小時  對敏感族群不健康  101
# 71       金門    金門縣     臭氧八小時  對敏感族群不健康  126
# 72       馬公    澎湖縣     臭氧八小時  對敏感族群不健康  108
# 85   屏東(枋山)    屏東縣     臭氧八小時  對敏感族群不健康  108

# %% [markdown]
# # 查詢空氣污染指標物（pollutant）有哪些？

# %%
df['pollutant'].unique()
# Out:
# array([nan, '臭氧八小時', '細懸浮微粒', '臭氧'], dtype=object)

# %% [markdown]
# # 請找出高雄市的測站資料

# %%
condition = df['county'] =='高雄市'
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 45       美濃    高雄市       NaN     良好   43
# 46       橋頭    高雄市     細懸浮微粒     普通   62
# 47       仁武    高雄市     細懸浮微粒     普通   63
# 48       鳳山    高雄市     細懸浮微粒     普通   67
# 49       大寮    高雄市     細懸浮微粒     普通   71
# 50       林園    高雄市     細懸浮微粒     普通   61
# 51       楠梓    高雄市     細懸浮微粒     普通   62
# 52       左營    高雄市     臭氧八小時     普通   61
# 53       前金    高雄市     細懸浮微粒     普通   58
# 54       前鎮    高雄市     細懸浮微粒     普通   54
# 55       小港    高雄市     細懸浮微粒     普通   61
# 68       復興    高雄市     細懸浮微粒     普通   58
# 79   高雄（湖內）    高雄市     細懸浮微粒     普通   52

# %% [markdown]
# # 計算各縣市的平均AQI

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 金門縣    126.000000
# 澎湖縣    108.000000
# 連江縣    101.000000
# 彰化縣     89.800000
# 苗栗縣     79.666667
# 雲林縣     78.250000
# 新竹市     77.000000
# 屏東縣     75.800000
# 桃園市     74.833333
# 新竹縣     74.000000
# 臺中市     72.500000
# 嘉義縣     72.000000
# 新北市     71.166667
# 臺北市     63.857143
# 臺南市     60.800000
# 高雄市     59.461538
# 嘉義市     54.000000
# 花蓮縣     48.000000
# 基隆市     47.000000
# 宜蘭縣     45.000000
# 臺東縣     44.000000
# 南投縣     43.000000
# Name: aqi, dtype: float64
